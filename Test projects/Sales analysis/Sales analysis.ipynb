# %% [markdown]
# # Sales analysis

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import os
from itertools import combinations
from collections import Counter

# %% [markdown]
# #### Task #1: Merge 12 months of sales data into a single file

# %%
all_months_data = pd.DataFrame()

files = [file for file in os.listdir('./Sales_Data/')]

for file in files:
    df = pd.read_csv('./Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data,df])

#all_months_data.to_csv('./Sales_Data/all_data.csv',index = False)

# %% [markdown]
# #### Read in updated dataframe

# %%
all_data = pd.read_csv('./Sales_Data/all_data.csv')
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ## Clean up data!

# %% [markdown]
# #### Drop rows of NaN

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df
# Out:
#        Order ID Product Quantity Ordered Price Each Order Date  \
# 1           NaN     NaN              NaN        NaN        NaN
# 356         NaN     NaN              NaN        NaN        NaN
# 735         NaN     NaN              NaN        NaN        NaN
# 1433        NaN     NaN              NaN        NaN        NaN
# 1553        NaN     NaN              NaN        NaN        NaN
# ...         ...     ...              ...        ...        ...
# 185176      NaN     NaN              NaN        NaN        NaN
# 185438      NaN     NaN              NaN        NaN        NaN
# 186042      NaN     NaN              NaN        NaN        NaN
# 186548      NaN     NaN              NaN        NaN        NaN
# 186826      NaN     NaN              NaN        NaN        NaN
#
#        Purchase Address
# 1                   NaN
# 356                 NaN
# 735                 NaN
# 1433                NaN
# 1553                NaN
# ...                 ...
# 185176              NaN
# 185438              NaN
# 186042              NaN
# 186548              NaN
# 186826              NaN
#
# [545 rows x 6 columns]

# %%
all_data.dropna(how='all',inplace=True)

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# #### Find and delete 'Or'

# %%
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']

# %% [markdown]
# #### Convert quantity and price to numerical

# %%
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])

# %% [markdown]
# ## Add additional columns

# %% [markdown]
# #### Task 2: Add month column

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype(int)
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# #### Task 3: Add sales column

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %% [markdown]
# #### Task 4: Add a city column

# %%
def get_city(address):
    return address.split(',')[1][1:]
    
def get_state(address):
    return address.split(',')[2].split(' ')[1]
    
all_data['City'] = all_data['Purchase Address'].apply(lambda x: f'{get_city(x)} ({get_state(x)})')

# %% [markdown]
# #### Question 1: What is the best month for sales? How much was earned that month?

# %%
results = all_data.groupby('Month').sum()

# %%
# %matplotlib inline

months = np.arange(1,13)
fig , ax = plt.subplots(figsize = (10,6))

ax.bar(months,results['Sales']);

ax.set(
    title = 'Total sales per month',
    xlabel = 'Months',
    ylabel = 'Sales in M $'
);

ax.set_xticks(months);

# %% [markdown]
# #### Question 2: What city had the highest number of sales

# %%
results =  all_data.groupby('City')['Sales'].sum().reset_index()

# %%
results.sort_values(by='Sales', ascending=False)
# Out:
#                  City       Sales
# 8  San Francisco (CA)  8262203.91
# 4    Los Angeles (CA)  5452570.80
# 5  New York City (NY)  4664317.43
# 2         Boston (MA)  3661642.01
# 0        Atlanta (GA)  2795498.58
# 3         Dallas (TX)  2767975.40
# 9        Seattle (WA)  2747755.48
# 7       Portland (OR)  1870732.34
# 1         Austin (TX)  1819581.75
# 6       Portland (ME)   449758.27

# %%
fig , ax = plt.subplots(figsize = (10,6))

cities = results['City']

ax.bar(cities,results['Sales']);

ax.set(
    title = 'Total sales per month',
    xlabel = 'City',
    ylabel = 'Sales in M $'
);

plt.xticks(cities,rotation = 'vertical',size = 8);

# %% [markdown]
# #### Question 3: What time should we show advertisments to increase purchasing ?

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'], format = 'mixed', dayfirst=True)
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-07-04 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-12-04 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-12-04 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                City
# 0       Dallas (TX)
# 2       Boston (MA)
# 3  Los Angeles (CA)
# 4  Los Angeles (CA)
# 5  Los Angeles (CA)

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data['Minute'] = all_data['Order Date'].dt.minute
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-07-04 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-12-04 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-12-04 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                City  Hour  Minute
# 0       Dallas (TX)     8      46
# 2       Boston (MA)    22      30
# 3  Los Angeles (CA)    14      38
# 4  Los Angeles (CA)    14      38
# 5  Los Angeles (CA)     9      27

# %%
fig , ax = plt.subplots(figsize = (10,6))

results = all_data.groupby('Hour')
hours = [hour for hour, df in results]

ax.plot(hours,results.count());

ax.set(
    title = 'Orders per hour',
    xlabel = 'Hour',
    ylabel = 'Orders'
);
ax.grid()
plt.xticks(hours);

# %% [markdown]
# #### Around 11:00 and 18:00-19:00

# %%
sales_per_city_hour = all_data.groupby(['City', 'Hour']).size().reset_index(name='SalesCount')
max_sales_time_per_city = sales_per_city_hour.loc[sales_per_city_hour.groupby('City')['SalesCount'].idxmax()]
max_sales_time_per_city
# Out:
#                    City  Hour  SalesCount
# 19         Atlanta (GA)    19        1047
# 43          Austin (TX)    19         685
# 67          Boston (MA)    19        1401
# 85          Dallas (TX)    13        1013
# 107    Los Angeles (CA)    11        2025
# 139  New York City (NY)    19        1753
# 155       Portland (ME)    11         177
# 180       Portland (OR)    12         733
# 211  San Francisco (CA)    19        3106
# 228        Seattle (WA)    12        1012

# %% [markdown]
# #### Question 4: What products are most often sold together?

# %%
df = pd.DataFrame(all_data[all_data['Order ID'].duplicated(keep=False)])

df_grouped = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))

count = Counter()

for row in df_grouped:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

df_pairs = pd.DataFrame( count.most_common(15),columns=['Products', 'Orders'])

df_pairs
# Out:
#                                              Products  Orders
# 0                  (iPhone, Lightning Charging Cable)    2140
# 1                (Google Phone, USB-C Charging Cable)    2116
# 2                          (iPhone, Wired Headphones)     987
# 3                    (Google Phone, Wired Headphones)     949
# 4                  (iPhone, Apple Airpods Headphones)     799
# 5             (Vareebadd Phone, USB-C Charging Cable)     773
# 6          (Google Phone, Bose SoundSport Headphones)     503
# 7            (USB-C Charging Cable, Wired Headphones)     452
# 8                 (Vareebadd Phone, Wired Headphones)     327
# 9        (Lightning Charging Cable, Wired Headphones)     253
# 10  (Lightning Charging Cable, Apple Airpods Headp...     214
# 11  (USB-C Charging Cable, Bose SoundSport Headpho...     211
# 12      (Vareebadd Phone, Bose SoundSport Headphones)     182
# 13       (Apple Airpods Headphones, Wired Headphones)     170
# 14     (Bose SoundSport Headphones, Wired Headphones)     140

# %% [markdown]
# #### Question 5: What product sold the most ?

# %%
product_group = all_data.groupby('Product')
quantity_ordered = product_group.sum(numeric_only = True)['Quantity Ordered']

keys = [pair for pair, df in product_group]
plt.bar(keys, quantity_ordered)
plt.xticks(keys, rotation='vertical', size=8)
plt.show()

# %%
# Referenced: https://stackoverflow.com/questions/14762181/adding-a-y-axis-label-to-secondary-y-axis-in-matplotlib

prices = all_data.groupby('Product')['Price Each'].mean()

fig, ax1 = plt.subplots()

ax2 = ax1.twinx()
ax1.bar(keys, quantity_ordered, color='g')
ax2.plot(keys, prices, color='b')

ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('Price ($)', color='b')
ax1.set_xticks(keys)
ax1.set_xticklabels(keys, rotation='vertical', size=8);

# %% [markdown]
# #### Question 6: How many iphones did Dallas sell in Mars ?

# %%
iphones = all_data.loc[(all_data['City'] == 'Dallas (TX)') & (all_data['Month'] == 3 ) & (all_data['Product'] == 'iPhone')]

# %%
iphones
# Out:
#        Order ID Product  Quantity Ordered  Price Each      Order Date  \
# 105289   162033  iPhone                 1       700.0  03/19/19 11:06
# 105575   162305  iPhone                 1       700.0  03/26/19 17:08
# 105670   162391  iPhone                 1       700.0  03/16/19 13:24
# 105672   162392  iPhone                 1       700.0  03/09/19 10:55
# 106077   162782  iPhone                 1       700.0  03/31/19 13:13
# 106458   163144  iPhone                 1       700.0  03/27/19 23:50
# 106705   163376  iPhone                 1       700.0  03/04/19 15:51
# 106743   163414  iPhone                 1       700.0  03/11/19 16:13
# 106991   163653  iPhone                 1       700.0  03/31/19 17:42
# 107535   164174  iPhone                 1       700.0  03/27/19 22:16
# 107717   164348  iPhone                 1       700.0  03/02/19 09:27
# 107766   164391  iPhone                 1       700.0  03/28/19 21:06
# 108006   164620  iPhone                 1       700.0  03/25/19 18:02
# 108536   165121  iPhone                 1       700.0  03/30/19 16:20
# 108691   165264  iPhone                 1       700.0  03/27/19 13:33
# 110612   167111  iPhone                 1       700.0  03/19/19 13:41
# 111297   167761  iPhone                 1       700.0  03/07/19 17:48
# 111922   168366  iPhone                 1       700.0  03/12/19 15:41
# 112172   168607  iPhone                 1       700.0  03/20/19 08:42
# 112269   168698  iPhone                 1       700.0  03/30/19 10:35
# 112783   169192  iPhone                 1       700.0  03/28/19 09:38
# 112861   169266  iPhone                 1       700.0  03/10/19 19:58
# 113766   170125  iPhone                 1       700.0  03/02/19 12:36
# 113852   170207  iPhone                 1       700.0  03/23/19 13:19
# 114613   170940  iPhone                 1       700.0  03/20/19 17:33
# 114797   171114  iPhone                 1       700.0  03/07/19 09:14
# 115024   171334  iPhone                 1       700.0  03/17/19 12:10
# 115724   172009  iPhone                 1       700.0  03/25/19 22:55
# 117061   173276  iPhone                 1       700.0  03/15/19 08:35
# 117527   173716  iPhone                 1       700.0  03/06/19 11:27
# 118055   174227  iPhone                 1       700.0  03/28/19 14:16
# 119261   175377  iPhone                 1       700.0  03/29/19 13:11
# 119486   175594  iPhone                 1       700.0  03/07/19 16:26
# 119734   175832  iPhone                 1       700.0  03/26/19 16:59
# 120109   176193  iPhone                 1       700.0  03/10/19 01:11
#
#                            Purchase Address  Month  Sales         City
# 105289     267 Johnson St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 105575     460 Hickory St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 105670    444 Highland St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 105672         692 6th St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 106077   931 Jefferson St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 106458        160 West St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 106705        694 11th St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 106743        630 Lake St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 106991      845 Church St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 107535      483 Cherry St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 107717     570 Johnson St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 107766        675 Pine St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 108006         841 2nd St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 108536        597 11th St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 108691      926 Spruce St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 110612      863 Wilson St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 111297      530 Center St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 111922         258 5th St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 112172         68 Pine St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 112269      562 Church St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 112783  344 Washington St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 112861    182 Chestnut St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 113766         814 6th St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 113852      701 Sunset St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 114613      251 Spruce St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 114797      458 Church St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 115024      611 Center St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 115724       956 River St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 117061        460 Park St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 117527      303 Center St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 118055         639 8th St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 119261         853 5th St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 119486     246 Dogwood St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 119734        626 13th St, Dallas, TX 75001      3  700.0  Dallas (TX)
# 120109         443 4th St, Dallas, TX 75001      3  700.0  Dallas (TX)

# %%
iphones['Quantity Ordered'].sum()
# Out:
# 35
