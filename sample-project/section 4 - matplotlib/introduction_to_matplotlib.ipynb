# %% [markdown]
# # Introduction to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot()
plt.show()

# %%
# 2nd method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method (recommended)

fig, ax = plt.subplots()
ax.plot(x,[50,100,200,250]);
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## matplotlib excemple worksflow

# %%
# 0. import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline 
import matplotlib.pyplot as plt

# 1. Prepare data 
x = [1,2,3,4]
y = [11,22,33,44]

# 2. Setup plot 
# figsize (x,y) (width, heigt)
fig, ax = plt.subplots(
    figsize = (10,10)
)

# 3. Plot data 
ax.plot(x,y)

# 4. customize plot 

ax.set(
    title="Simple plot",
    xlabel="x-axis",
    ylabel="y-axis"
)

# 5. Save & show 
fig.savefig('../images/sample-plot.png')

# %%
# 1. Prepare data 
x = np.array([1,2,3,4,5,6,7])
y = np.array([20,13,13,13,8,17,4])


# 2. Setup plot 
# figsize (x,y) (width, height)
fig, ax = plt.subplots(
    figsize = (7,7)
)

# 3. Plot data 
ax.plot(x,y)

# 4. customize plot 

ax.set(
    title="Daily temprature",
    xlabel="Time",
    ylabel="temprature (c)"
);

# 5. Save & show 
fig.savefig('../images/sample-plot2.png')

# %% [markdown]
# ## Making figures with Numpy arrays
#
# * line plot
# * scatter plot
# * bar plot
# * histogram
# * subplots

# %%
# create data 
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# plot the data 
fig , ax = plt.subplots()
ax.plot(x,x**2)

# %%
# Use the same data to create scatter plot
fig , ax = plt.subplots()
ax.scatter(x,np.exp(x));

# %%
# Another scatter 
fig,ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
# Make a plot from dictionary
nut_butter_prices = {
    'Almond butter': 10,
    'Peaunt butter': 8,
    'Cashew butter': 12
}

fig , ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(
    title='Nadines nut butter store',
    ylabel="Price (Sek)",
    xlabel="Items"
);

# %%
 fig , ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
# make some data
x = np.random.randn(1000)
fix , ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Tow options for subplots

# %%
# Subplot option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(
    nrows = 2,
    ncols = 2,
    figsize = (10,5)    
)
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# subplot option 2 
fig , ax = plt.subplots(
    nrows=2,
    ncols=2,
    figsize=(10,5)
);

#plot to each different index
ax[0,0].plot(x,x*2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## plotting from pandas dataframe

# %%
# make a df 
car_sales = pd.read_csv('../data/car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
np.random.seed(120)
df = pd.DataFrame(np.random.randn(1000),index = pd.date_range('2024/06/29',periods=1000))
df = df.cumsum();
df.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace(r'[\$\,]','',regex=True).astype(float).round(decimals = 0).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Sale date'] = pd.date_range('2024/05/01',periods = len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale date
# 0  Toyota  White         150043      4   4000 2024-05-01
# 1   Honda    Red          87899      4   5000 2024-05-02
# 2  Toyota   Blue          32549      3   7000 2024-05-03
# 3     BMW  Black          11179      5  22000 2024-05-04
# 4  Nissan  White         213095      4   3500 2024-05-05
# 5  Toyota  Green          99213      4   4500 2024-05-06
# 6   Honda   Blue          45698      4   7500 2024-05-07
# 7   Honda   Blue          54738      4   7000 2024-05-08
# 8  Toyota  White          60000      4   6250 2024-05-09
# 9  Nissan  White          31600      4   9700 2024-05-10

# %%
car_sales['Total Sales'] = car_sales['Price'].cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-05-01         4000
# 1   Honda    Red          87899      4   5000 2024-05-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-05-03        16000
# 3     BMW  Black          11179      5  22000 2024-05-04        38000
# 4  Nissan  White         213095      4   3500 2024-05-05        41500
# 5  Toyota  Green          99213      4   4500 2024-05-06        46000
# 6   Honda   Blue          45698      4   7500 2024-05-07        53500
# 7   Honda   Blue          54738      4   7000 2024-05-08        60500
# 8  Toyota  White          60000      4   6250 2024-05-09        66750
# 9  Nissan  White          31600      4   9700 2024-05-10        76450

# %%
# Plot total sales

car_sales.plot(x='Sale date', y='Total Sales');

# %%
 car_sales.plot(x='Odometer (KM)', y='Price',kind='scatter');

# %%
# Bar graph
x = np.random.rand(10,4)
x
df = pd.DataFrame(x, columns = ['A','B','C','D'])
df
# Out:
#           A         B         C         D
# 0  0.547043  0.320481  0.891836  0.982825
# 1  0.039574  0.171216  0.842515  0.946406
# 2  0.058134  0.030845  0.759734  0.141644
# 3  0.273333  0.942302  0.009055  0.505631
# 4  0.728828  0.461810  0.328523  0.234924
# 5  0.459152  0.890692  0.624842  0.884202
# 6  0.659043  0.532404  0.779642  0.257685
# 7  0.190064  0.752394  0.546968  0.625979
# 8  0.603500  0.493169  0.073590  0.103015
# 9  0.704948  0.167201  0.890001  0.488262

# %%
df.plot.bar();

# %%
x = np.random.randint(10,50,size=(8,4))
x
df2 = pd.DataFrame(x, columns = ['A','B','C','D'])
df2
# Out:
#     A   B   C   D
# 0  44  41  14  15
# 1  30  38  28  30
# 2  40  49  45  46
# 3  10  17  20  36
# 4  12  13  25  24
# 5  32  43  29  15
# 6  38  12  13  16
# 7  10  38  19  43

# %%
df2.plot(kind='bar');

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale date  Total Sales
# 0  Toyota  White         150043      4   4000 2024-05-01         4000
# 1   Honda    Red          87899      4   5000 2024-05-02         9000
# 2  Toyota   Blue          32549      3   7000 2024-05-03        16000
# 3     BMW  Black          11179      5  22000 2024-05-04        38000
# 4  Nissan  White         213095      4   3500 2024-05-05        41500
# 5  Toyota  Green          99213      4   4500 2024-05-06        46000
# 6   Honda   Blue          45698      4   7500 2024-05-07        53500
# 7   Honda   Blue          54738      4   7000 2024-05-08        60500
# 8  Toyota  White          60000      4   6250 2024-05-09        66750
# 9  Nissan  White          31600      4   9700 2024-05-10        76450

# %%
car_sales.plot(x='Make',y='Odometer (KM)',kind='bar');

# %%
# Histograms
car_sales['Odometer (KM)'].plot.hist(bins=10);

# %%
heart_disease = pd.read_csv('../data/heart-disease.csv')
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histogram of age 
heart_disease['age'].plot.hist();

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True);

# %%
over_50 = heart_disease[heart_disease['age']>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.plot(
    kind='scatter',
    x = 'age',
    y = 'chol',
    c = 'target'
);

# %%
# OO mehtod mixed with pyplot
fig,ax = plt.subplots(
    figsize=(10,6)
)
over_50.plot(
    kind='scatter',
    x = 'age',
    y = 'chol',
    c = 'target',
    ax = ax
);

ax.set_xlim([45,90])
# Out:
# (45.0, 90.0)

# %%
# OO method from scratch
fig , ax = plt.subplots(figsize=(10,6))

colors = np.where(over_50["target"]==1,'#d63031','#00b894')
# Plot the data
scatter = ax.scatter(
    x = over_50['age'],
    y = over_50['chol'],
    c =  over_50['target']
);

# customize 
ax.set(
    title = 'Heart disease and cholesterol levels',
    xlabel = 'Age',
    ylabel = 'Cholestrol',
);

# add a legend 
ax.legend(*scatter.legend_elements(), title='Target');

# add a horizontal line
ax.axhline(
    over_50['chol'].mean(),
    linestyle='--',
    c='#636e72'    
);

# %% [markdown]
# ## Customizing matplotlib plots

# %%
# subplot of chol , age and thalach
fig , ((ax0, ax1)) = plt.subplots(
    nrows = 2,
    ncols = 1,
    figsize = (10,10),
    sharex = True 
)

## add data to ax0 
scatter = ax0.scatter(
    x = over_50['age'],
    y = over_50['chol'],
    c = over_50['target'],
)

# customize ax0

ax0.set(
    title ="heart disease colestrol over age",
    ylabel = 'Cholestrol'
)

ax0.legend(*scatter.legend_elements(),title = 'Target')

# add a mean line
ax0.axhline(
    y = over_50['chol'].mean(),
    linestyle = '--',
    c ='#636e72'    
)

## add data to ax1 

scatter = ax1.scatter(
    x = over_50['age'],
    y = over_50['thalach'],
    c = over_50['target'],
)

ax1.set(
    title ="heart disease max heart rate over age",
    xlabel = 'Age',
    ylabel = 'Max Heart rate'
)

ax1.legend(*scatter.legend_elements(),title = 'Target')

# add a mean line
ax1.axhline(
    y = over_50['thalach'].mean(),
    linestyle = '--',
    c ='#636e72'
);

fig.suptitle('Heart disease analysis', fontsize = 16 , fontweight = 'bold');

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-whitegrid')
# subplot of chol , age and thalach
fig , ((ax0, ax1)) = plt.subplots(
    nrows = 2,
    ncols = 1,
    figsize = (10,10),
    sharex = True 
)

## add data to ax0 
scatter = ax0.scatter(
    x = over_50['age'],
    y = over_50['chol'],
    c = over_50['target'],
    cmap = 'RdYlGn'
)

# customize ax0

ax0.set(
    title ="heart disease colestrol over age",
    ylabel = 'Cholestrol'
)

ax0.set_xlim([50,80])

ax0.legend(*scatter.legend_elements(),title = 'Target')

# add a mean line
ax0.axhline(
    y = over_50['chol'].mean(),
    linestyle = '--',
    c ='#636e72'    
)

## add data to ax1 

scatter = ax1.scatter(
    x = over_50['age'],
    y = over_50['thalach'],
    c = over_50['target'],
    cmap = 'bwr'
)

ax1.set(
    title ="heart disease max heart rate over age",
    xlabel = 'Age',
    ylabel = 'Max Heart rate'
)

ax1.set_ylim([60,200])

ax1.legend(*scatter.legend_elements(),title = 'Target')

# add a mean line
ax1.axhline(
    y = over_50['thalach'].mean(),
    linestyle = '--',
    c ='#636e72'
);

fig.suptitle('Heart disease analysis', fontsize = 16 , fontweight = 'bold');

# %%
fig.savefig('../images/hds.png', facecolor='white')
